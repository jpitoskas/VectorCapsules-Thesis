# %%
import os
import natsort
import re
import pandas as pd

# %%
    models_dirs = os.listdir('remote_experiments')
    models_dirs = [os.path.join('remote_experiments', model_dir) for model_dir in natsort.natsorted(models_dirs, reverse=False)]

    models = {}

    for model_dir in models_dirs:
        model_id = int(model_dir.split('_')[-1])
        trainlogs_dir = os.path.join(model_dir, f'trainlogs_{model_id}.log')
        with open(trainlogs_dir) as file:
            model_vars = {}
            for line in file:
                if ":" in line:
                    line = line.replace('\n','')
                    name, var = line.partition(":")[::2]
                    model_vars[name.strip()] = var.strip()
                else:
                    break

            models[model_id] = model_vars

# %%
for model_dir in models_dirs:
    model_id = int(model_dir.split('_')[-1])
    trainlogs_dir = os.path.join(model_dir, f'trainlogs_{model_id}.log')
    with open(trainlogs_dir) as file:
        train_losses = []
        valid_losses = []
        test_losses = []

        train_accuracies = []
        valid_accuracies = []
        test_accuracies = []
        
        for line in file:
            loss = re.search('Average loss: ([\w.]+)', line).group(1) if re.search('Average loss: ([\w.]+)', line) else None
            accuracy = re.search(re.search('Accuracy: ([\w/]+)', line).group(1) + ' \(([\w.]+)', line).group(1) if re.search('Accuracy: ([\w/]+)', line) else None
            if loss and accuracy:
                loss = float(loss)
                accuracy = float(accuracy)
                if "Train" in line:
                    train_losses.append(loss)
                    train_accuracies.append(accuracy)
                elif "Validation" in line:
                    valid_losses.append(loss)
                    valid_accuracies.append(accuracy)
                elif "Test" in line:
                    test_losses.append(loss)
                    test_accuracies.append(accuracy)
                    
    models[model_id]["train_losses"] = train_losses
    models[model_id]["valid_losses"] = valid_losses
    models[model_id]["test_losses"] = test_losses
    
    models[model_id]["train_accuracies"] = train_accuracies
    models[model_id]["valid_accuracies"] = valid_accuracies
    models[model_id]["test_accuracies"] = test_accuracies
    
    models[model_id]["best_train_loss"] = str(round(min(train_losses), 4))
    models[model_id]["best_valid_loss"] = str(round(min(valid_losses), 4))
    models[model_id]["best_test_loss"] = str(round(min(test_losses), 4))
    
    models[model_id]["best_train_accuracy"] = str(round(max(train_accuracies), 2))
    models[model_id]["best_valid_accuracy"] = str(round(max(valid_accuracies), 2))
    models[model_id]["best_test_accuracy"] = str(round(100-max(test_accuracies), 2)) + ' %'
    
    models[model_id]["epochs"] = len(models[model_id]["test_accuracies"])

# %%
with open('prints.txt', 'w') as prints_fd:
    models_by_dataset = dict(sorted(models.items(), key=lambda x: (x[1]['dataset'], float(x[1]['best_test_accuracy'][:-1])), reverse=False))
    for model_id, model_vars in zip(models_by_dataset.keys(), models_by_dataset.values()):
        print(f"MODEL {model_id}:\n", file=prints_fd)
        print(f"- Dataset: {model_vars['dataset'].upper()}", file=prints_fd)
        print(f"- Batch Size: {model_vars['batch_size']}", file=prints_fd)
        print(f"- Epochs: {model_vars['epochs']}", file=prints_fd)
        print(f"- Learning Rate: {model_vars['lr']}", file=prints_fd)
        if 'scheduler' in model_vars.keys():
            print(f"- Scheduler: {model_vars['scheduler'].capitalize()}", file=prints_fd)
        else:
            print("- Scheduler: Plateau", file=prints_fd)


    #     print(f")
        print("- Routing Algorithm: " + re.sub(r'(\w)([A-Z])', r'\1 \2', model_vars['routing_module']), file=prints_fd)
        if model_vars['extra_conv'] == "True":
            print("- Extra Convolutional Layer", file=prints_fd)

        if model_vars['routing_module'] == "AgreementRouting":
            print("- Number of Iterations: ", model_vars['routing_iterations'], file=prints_fd)
        elif model_vars['routing_module'] == "WeightedAverageRouting":
            pass
        elif model_vars['routing_module'] == "DropoutWeightedAverageRouting":
            print("- Dropout Probability: ", model_vars['dropout_probability'], file=prints_fd)
        elif model_vars['routing_module'] == "SubsetRouting":
            print("- Subset Fraction: ", model_vars['subset_fraction'], file=prints_fd)
        elif model_vars['routing_module'] == "RansacRouting":
            print("- Number of Hypotheses: ", model_vars['n_hypotheses'], file=prints_fd)
            print("- Subset Fraction: ", model_vars['subset_fraction'], file=prints_fd)

        print(f"- Test Accuracy: {model_vars['best_test_accuracy']}%", file=prints_fd)


        print('\n\n', file=prints_fd)

# %%
to_drop  = ['no_cuda', 'seed', 'with_reconstruction', 'padding', 'brightness', 
            'contrast', 'crop_dim', 'num_workers', 'test_affNIST',  'cuda', 'channels',
            'n_classes', 'Hin', 'Win', 'train_losses', 'valid_losses',
            'test_losses', 'train_accuracies', 'valid_accuracies',
            'test_accuracies', 'best_train_loss', 'best_valid_loss',
            'best_test_loss', 'best_train_accuracy', 'best_valid_accuracy', 'routing_iterations', 'load_model_id',
           'extra_caps_dim', 'extra_conv']



df = pd.DataFrame()

for model_id, model_vars in zip(models_by_dataset.keys(), models_by_dataset.values()):
#     tmp = pd.DataFrame([model_vars], index=[model_id]).rename_axis('Model ID')
    tmp = pd.DataFrame([model_vars], index=[model_id])
    df = df.append(tmp)
df = df.drop(to_drop, axis = 1)


# Ignore useless hyperparameters depending on the Routing Module
df.loc[df["routing_module"] == "WeightedAverageRouting", ("dropout_probability", "subset_fraction", "n_hypotheses", "metric")] = ("-", "-", "-", "-")
df.loc[df["routing_module"] == "DropoutWeightedAverageRouting", ("subset_fraction", "n_hypotheses", "metric")] = ("-", "-", "-")
df.loc[df["routing_module"] == "SubsetRouting", ("dropout_probability", "n_hypotheses")] = ("-", "-")                                                        
df.loc[df["routing_module"] == "RansacRouting", "dropout_probability"] = "-"  

df.loc[(df["routing_module"] == "SubsetRouting") & (pd.isna(df["metric"])), "metric"] = "MSE"
df.loc[(df["routing_module"] == "RansacRouting") & (pd.isna(df["metric"])), "metric"] = "MSE" 

# Set "-" if no Scheduler
df.loc[df["scheduler"] == "None", "scheduler"] = "-"
df.loc[pd.isna(df["scheduler"]), "scheduler"] = "-" 

# Set "-" if no extra capsule layer
df.loc[pd.isna(df["extra_caps"]), "extra_caps"] = "-" 

# # Set "-" if no extra capsule layer
# df.loc[pd.isna(df["extra_caps"]), "extra_caps"] = "-" 

# Place Accuracy column last
test_acc_column = df.pop('best_test_accuracy')
df.insert(df.shape[1], 'best_test_accuracy', test_acc_column)


# Rename routing modules (to make them shorter)
df.loc[df["routing_module"] == "WeightedAverageRouting", "routing_module"] = "WeightedAvg"
df.loc[df["routing_module"] == "DropoutWeightedAverageRouting", "routing_module"] = "Dropout"
df.loc[df["routing_module"] == "SubsetRouting", "routing_module"] = "Subset"                                                        
df.loc[df["routing_module"] == "RansacRouting", "routing_module"] = "Ransac"


# Rename Columns
# df.rename(columns = {'best_test_accuracy':'Test Accuracy (%)'}, inplace = True)
df.rename(columns = {'best_test_accuracy':'Test Error (%)'}, inplace = True)
df.rename(columns = {'dataset':'Dataset'}, inplace = True)
df.rename(columns = {'batch_size':'Batch Size'}, inplace = True)
df.rename(columns = {'epochs':'Epochs'}, inplace = True)
df.rename(columns = {'lr':'Learning Rate'}, inplace = True)
df.rename(columns = {'routing_module':'Routing Module'}, inplace = True)
df.rename(columns = {'dropout_probability':'Dropout Probability'}, inplace = True)
df.rename(columns = {'scheduler':'Scheduler'}, inplace = True)
df.rename(columns = {'subset_fraction':'Subset Fraction'}, inplace = True)
df.rename(columns = {'n_hypotheses':'Number of Hypotheses'}, inplace = True)
df.rename(columns = {'metric':'Similarity Metric'}, inplace = True)

df.replace('-', u'\u2014', inplace=True)

# %% [markdown]
# # **Routing Algorithms**
# Έστω $V$ το σύνολο των votes των child capsules (layer $L$) για τα poses των parent capsules (layer $L+1$). O $V$ αποτελείται αποτελείται από $V_{ij}$ vectors που δείχνουν το vote του child capsule $i$ για το pose του $j$ parent capsule.
#
# Έστω $ V_j = [V_{1j},V_{2j},\ldots,V_{ij},\ldots] $ το σύνολο των votes των child capsules προς τον parent j.
#
#
#
# ## **Weighted Average Routing**
#
#
# 1. $procedure$ $WeightedAverageRouting$ $(V_j):$
#
# 2. $\quad$ $\mu_{j} \leftarrow \frac{\sum_i{\lVert  V_{ij}  \rVert \cdot V_{ij}}}{\sum_i{\lVert  V_{ij}  \rVert}} $ $\quad$ $\quad$ $\quad$
#
# 3. $\quad$ $return$ $\mu_{j}$
#
#
#
# ## **Dropout Weighted Average Routing**
#
#
# Έστω $p$ η dropout πιθανότητα, δηλαδή η πιθανότητα να απενεργοποιηθεί ένα child capsule vote προς τον parent $j$.
#
# 1. $procedure$ $DropoutWeightedAverageRouting$ $(V_j, p):$
#
# 2. $\quad$ $r_{j} \leftarrow  [r_{1j},r_{2j},\ldots,r_{ij},\ldots] $, όπου $r_{ij} \thicksim Bernoulli(p) $
#
# 3. $\quad$ $U_j \leftarrow r_{j} \cdot V_j$ $\quad \quad$ $\quad$ $($ i.e. $U_h=[0,V_{2j},V_{3j}, 0 \ldots,V_{ij},\ldots]$ $)$
#
# 4. $\quad$ $\mu_{j} \leftarrow \frac{\sum_i{\lVert  U_{ij}  \rVert \cdot U_{ij}}}{\sum_i{\lVert  U_{ij}  \rVert}} $ $\quad$ $\quad$ $\quad$
#
# 3. $\quad$ $return$ $\mu_{j}$
#
#
#
# ## **Subset Routing**
#
#
# Έστω $M$ το πλήθος των child votes $V_{ij}$ που θα ενεργοποιούνται προκειμένου να συνεισφέρουν στον υπολογισμό του pose του parent $j$
#
#
# 1. $procedure$ $SubsetRouting$ $(V_j, M):$
#
# 2. $\quad$ $\mu_{j} \leftarrow \frac{\sum_i{\lVert  V_{ij}  \rVert \cdot V_{ij}}}{\sum_i{\lVert  V_{ij}  \rVert}} $ $\quad$ $\quad$ $\quad$
#
# 3. $\quad$ $L_{j} \leftarrow  \lVert \mu_{j} -  V_{ij} \rVert $
#
# 4. $\quad$ $threshold_j \leftarrow  M_{th}$ smallest loss in $L_j$
#
# 5. $\quad$ $r_{j} \leftarrow$ vector with the $i_{th}$ being $1$ if $L_{ij} \leq threshold_j$ and  $0$ otherwise
#
# 6. $\quad$ $U_j \leftarrow r_{j} \cdot V_j$ $\quad \quad$ $\quad$ $($ i.e. $U_h=[0,V_{2j},V_{3j}, 0 \ldots,V_{ij},\ldots]$ containing $M$ non-zero vectors $)$
#
# 7. $\quad$ $\mu'_{j} \leftarrow \frac{\sum_i{\lVert  U_{ij}  \rVert \cdot U_{ij}}}{\sum_i{\lVert  U_{ij}  \rVert}}$
#
# 8. $\quad$ $return$ $\mu'_{j}$
#
#
#
# ## **Ransac Routing**
#
#
# Έστω $H$ το πλήθος των hypotheses που θα κάνουμε, και $M$ το πλήθος των child votes $V_{ij}$ που θα ενεργοποιούνται προκειμένου να συνεισφέρουν στον υπολογισμό του pose του parent $j$.
#
#
# 1. $procedure$ $RansacRouting$ $(V_j, H, M):$
#
# 2. $\quad$ for $H$ iterations do:
#
# 3. $\quad \quad$ $r_{j,h} \leftarrow$ random vector with the $i_{th}$ element is either $1$ or $0$ indicating if the $i_{th}$ capsule vote is activated or not ($M$ $1_s$ in total)
#
# 4. $\quad \quad$ $U_h \leftarrow r_{j,h} \cdot V_j$ $\quad \quad$ $\quad$ $($ i.e. $U_h=[0,V_{2j},V_{3j}, 0 \ldots,V_{ij},\ldots]$ containing $M$ non-zero vectors $)$
#
# 5. $\quad \quad$ $\mu_{j,h} \leftarrow \frac{\sum_i{\lVert  U_{h,i}  \rVert \cdot U_{h,i}}}{\sum_i{\lVert  U_{h,i}  \rVert}} $ $\quad$ $\quad$ $\quad$ $($ we have to choose the optimal $\mu_{j,h}$ that minimizes the following loss $)$
#
# 6. $\quad \quad$ $L_{j,h} \leftarrow  \sum_i{ \lVert \mu_{j,h} -  V_{ij} \rVert} $
#
# <!-- 6. $\quad \quad$ $L_{j,h} \leftarrow - \sum_i{\log{(\lVert  V_{ij}  \rVert)} \lVert \mu_{j,h} -  V_{ij} \rVert} $ -->
#
# 7. $\quad$ $h^{*} \leftarrow \arg \min_{h} (L_{j,h})$
#
# 8. $\quad$ $U^{*}_j \leftarrow r_{j,h^{*}} \cdot V_j$ $\quad \quad$ $\quad$ $($ i.e. $U^{*}_h=[0,V_{2j},V_{3j}, 0 \ldots,V_{ij},\ldots]$ containing $M$ non-zero vectors $)$
#
# 9. $\quad$ $\mu^{*}_{j} \leftarrow \frac{\sum_i{\lVert  U^{*}_{ij}  \rVert \cdot U^{*}_{ij}}}{\sum_i{\lVert  U^{*}_{ij}  \rVert}} $ $\quad$ $\quad$ $\quad$
#
# 10. $\quad$ $return$ $\mu^{*}_{j}$

# %%
def display_df(df, dataset):
    
    df = df.loc[df['Dataset'] == dataset]
    
    # Add styles
    dfStyler = df.style.set_properties(**{'text-align': 'center'})
    dfStyler = dfStyler.set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
    display(dfStyler)
    return

# %%
datasets = ['mnist', 'smallnorb', 'fashionmnist', 'svhn', 'cifar10']
BOLD = '\033[1m'
UNDERLINE = '\033[4m'
UNDERLINE_END = '\033[0m'

for dataset in datasets:
    print('\n\n\n' + BOLD + UNDERLINE + dataset.upper() + UNDERLINE_END + ":")
    display_df(df, dataset)
# Out:
# MNIST:
# <style type="text/css">
# #T_39cdf_ th {
#   text-align: center;
# }
# #T_39cdf_row0_col0, #T_39cdf_row0_col1, #T_39cdf_row0_col2, #T_39cdf_row0_col3, #T_39cdf_row0_col4, #T_39cdf_row0_col5, #T_39cdf_row0_col6, #T_39cdf_row0_col7, #T_39cdf_row0_col8, #T_39cdf_row0_col9, #T_39cdf_row0_col10, #T_39cdf_row0_col11, #T_39cdf_row0_col12, #T_39cdf_row1_col0, #T_39cdf_row1_col1, #T_39cdf_row1_col2, #T_39cdf_row1_col3, #T_39cdf_row1_col4, #T_39cdf_row1_col5, #T_39cdf_row1_col6, #T_39cdf_row1_col7, #T_39cdf_row1_col8, #T_39cdf_row1_col9, #T_39cdf_row1_col10, #T_39cdf_row1_col11, #T_39cdf_row1_col12, #T_39cdf_row2_col0, #T_39cdf_row2_col1, #T_39cdf_row2_col2, #T_39cdf_row2_col3, #T_39cdf_row2_col4, #T_39cdf_row2_col5, #T_39cdf_row2_col6, #T_39cdf_row2_col7, #T_39cdf_row2_col8, #T_39cdf_row2_col9, #T_39cdf_row2_col10, #T_39cdf_row2_col11, #T_39cdf_row2_col12, #T_39cdf_row3_col0, #T_39cdf_row3_col1, #T_39cdf_row3_col2, #T_39cdf_row3_col3, #T_39cdf_row3_col4, #T_39cdf_row3_col5, #T_39cdf_row3_col6, #T_39cdf_row3_col7, #T_39cdf_row3_col8, #T_39cdf_row3_col9, #T_39cdf_row3_col10, #T_39cdf_row3_col11, #T_39cdf_row3_col12, #T_39cdf_row4_col0, #T_39cdf_row4_col1, #T_39cdf_row4_col2, #T_39cdf_row4_col3, #T_39cdf_row4_col4, #T_39cdf_row4_col5, #T_39cdf_row4_col6, #T_39cdf_row4_col7, #T_39cdf_row4_col8, #T_39cdf_row4_col9, #T_39cdf_row4_col10, #T_39cdf_row4_col11, #T_39cdf_row4_col12, #T_39cdf_row5_col0, #T_39cdf_row5_col1, #T_39cdf_row5_col2, #T_39cdf_row5_col3, #T_39cdf_row5_col4, #T_39cdf_row5_col5, #T_39cdf_row5_col6, #T_39cdf_row5_col7, #T_39cdf_row5_col8, #T_39cdf_row5_col9, #T_39cdf_row5_col10, #T_39cdf_row5_col11, #T_39cdf_row5_col12, #T_39cdf_row6_col0, #T_39cdf_row6_col1, #T_39cdf_row6_col2, #T_39cdf_row6_col3, #T_39cdf_row6_col4, #T_39cdf_row6_col5, #T_39cdf_row6_col6, #T_39cdf_row6_col7, #T_39cdf_row6_col8, #T_39cdf_row6_col9, #T_39cdf_row6_col10, #T_39cdf_row6_col11, #T_39cdf_row6_col12, #T_39cdf_row7_col0, #T_39cdf_row7_col1, #T_39cdf_row7_col2, #T_39cdf_row7_col3, #T_39cdf_row7_col4, #T_39cdf_row7_col5, #T_39cdf_row7_col6, #T_39cdf_row7_col7, #T_39cdf_row7_col8, #T_39cdf_row7_col9, #T_39cdf_row7_col10, #T_39cdf_row7_col11, #T_39cdf_row7_col12, #T_39cdf_row8_col0, #T_39cdf_row8_col1, #T_39cdf_row8_col2, #T_39cdf_row8_col3, #T_39cdf_row8_col4, #T_39cdf_row8_col5, #T_39cdf_row8_col6, #T_39cdf_row8_col7, #T_39cdf_row8_col8, #T_39cdf_row8_col9, #T_39cdf_row8_col10, #T_39cdf_row8_col11, #T_39cdf_row8_col12, #T_39cdf_row9_col0, #T_39cdf_row9_col1, #T_39cdf_row9_col2, #T_39cdf_row9_col3, #T_39cdf_row9_col4, #T_39cdf_row9_col5, #T_39cdf_row9_col6, #T_39cdf_row9_col7, #T_39cdf_row9_col8, #T_39cdf_row9_col9, #T_39cdf_row9_col10, #T_39cdf_row9_col11, #T_39cdf_row9_col12, #T_39cdf_row10_col0, #T_39cdf_row10_col1, #T_39cdf_row10_col2, #T_39cdf_row10_col3, #T_39cdf_row10_col4, #T_39cdf_row10_col5, #T_39cdf_row10_col6, #T_39cdf_row10_col7, #T_39cdf_row10_col8, #T_39cdf_row10_col9, #T_39cdf_row10_col10, #T_39cdf_row10_col11, #T_39cdf_row10_col12, #T_39cdf_row11_col0, #T_39cdf_row11_col1, #T_39cdf_row11_col2, #T_39cdf_row11_col3, #T_39cdf_row11_col4, #T_39cdf_row11_col5, #T_39cdf_row11_col6, #T_39cdf_row11_col7, #T_39cdf_row11_col8, #T_39cdf_row11_col9, #T_39cdf_row11_col10, #T_39cdf_row11_col11, #T_39cdf_row11_col12 {
#   text-align: center;
# }
# </style>
# <table id="T_39cdf_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Dataset</th>
#       <th class="col_heading level0 col1" >Batch Size</th>
#       <th class="col_heading level0 col2" >Epochs</th>
#       <th class="col_heading level0 col3" >Learning Rate</th>
#       <th class="col_heading level0 col4" >Scheduler</th>
#       <th class="col_heading level0 col5" >extra_caps</th>
#       <th class="col_heading level0 col6" >Routing Module</th>
#       <th class="col_heading level0 col7" >Dropout Probability</th>
#       <th class="col_heading level0 col8" >Number of Hypotheses</th>
#       <th class="col_heading level0 col9" >Subset Fraction</th>
#       <th class="col_heading level0 col10" >Similarity Metric</th>
#       <th class="col_heading level0 col11" >architecture</th>
#       <th class="col_heading level0 col12" >Test Error (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39cdf_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_39cdf_row0_col0" class="data row0 col0" >mnist</td>
#       <td id="T_39cdf_row0_col1" class="data row0 col1" >512</td>
#       <td id="T_39cdf_row0_col2" class="data row0 col2" >150</td>
#       <td id="T_39cdf_row0_col3" class="data row0 col3" >0.001</td>
#       <td id="T_39cdf_row0_col4" class="data row0 col4" >—</td>
#       <td id="T_39cdf_row0_col5" class="data row0 col5" >—</td>
#       <td id="T_39cdf_row0_col6" class="data row0 col6" >WeightedAvg</td>
#       <td id="T_39cdf_row0_col7" class="data row0 col7" >—</td>
#       <td id="T_39cdf_row0_col8" class="data row0 col8" >—</td>
#       <td id="T_39cdf_row0_col9" class="data row0 col9" >—</td>
#       <td id="T_39cdf_row0_col10" class="data row0 col10" >—</td>
#       <td id="T_39cdf_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_39cdf_row0_col12" class="data row0 col12" >0.33 %</td>
#     </tr>
#     <tr>
#       <th id="T_39cdf_level0_row1" class="row_heading level0 row1" >13</th>
#       <td id="T_39cdf_row1_col0" class="data row1 col0" >mnist</td>
#       <td id="T_39cdf_row1_col1" class="data row1 col1" >512</td>
#       <td id="T_39cdf_row1_col2" class="data row1 col2" >150</td>
#       <td id="T_39cdf_row1_col3" class="data row1 col3" >0.001</td>
#       <td id="T_39cdf_row1_col4" class="data row1 col4" >exponential</td>
#       <td id="T_39cdf_row1_col5" class="data row1 col5" >—</td>
#       <td id="T_39cdf_row1_col6" class="data row1 col6" >WeightedAvg</td>
#       <td id="T_39cdf_row1_col7" class="data row1 col7" >—</td>
#       <td id="T_39cdf_row1_col8" class="data row1 col8" >—</td>
#       <td id="T_39cdf_row1_col9" class="data row1 col9" >—</td>
#       <td id="T_39cdf_row1_col10" class="data row1 col10" >—</td>
#       <td id="T_39cdf_row1_col11" class="data row1 col11" >nan</td>
#       <td id="T_39cdf_row1_col12" class="data row1 col12" >0.33 %</td>
#     </tr>
#     <tr>
#       <th id="T_39cdf_level0_row2" class="row_heading level0 row2" >40</th>
#       <td id="T_39cdf_row2_col0" class="data row2 col0" >mnist</td>
#       <td id="T_39cdf_row2_col1" class="data row2 col1" >512</td>
#       <td id="T_39cdf_row2_col2" class="data row2 col2" >150</td>
#       <td id="T_39cdf_row2_col3" class="data row2 col3" >0.001</td>
#       <td id="T_39cdf_row2_col4" class="data row2 col4" >plateau</td>
#       <td id="T_39cdf_row2_col5" class="data row2 col5" >—</td>
#       <td id="T_39cdf_row2_col6" class="data row2 col6" >Subset</td>
#       <td id="T_39cdf_row2_col7" class="data row2 col7" >—</td>
#       <td id="T_39cdf_row2_col8" class="data row2 col8" >—</td>
#       <td id="T_39cdf_row2_col9" class="data row2 col9" >0.3</td>
#       <td id="T_39cdf_row2_col10" class="data row2 col10" >MSE</td>
#       <td id="T_39cdf_row2_col11" class="data row2 col11" >nan</td>
#       <td id="T_39cdf_row2_col12" class="data row2 col12" >0.34 %</td>
#     </tr>
#     <tr>
#       <th id="T_39cdf_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_39cdf_row3_col0" class="data row3 col0" >mnist</td>
#       <td id="T_39cdf_row3_col1" class="data row3 col1" >256</td>
#       <td id="T_39cdf_row3_col2" class="data row3 col2" >150</td>
#       <td id="T_39cdf_row3_col3" class="data row3 col3" >0.001</td>
#       <td id="T_39cdf_row3_col4" class="data row3 col4" >—</td>
#       <td id="T_39cdf_row3_col5" class="data row3 col5" >—</td>
#       <td id="T_39cdf_row3_col6" class="data row3 col6" >Dropout</td>
#       <td id="T_39cdf_row3_col7" class="data row3 col7" >0.4</td>
#       <td id="T_39cdf_row3_col8" class="data row3 col8" >—</td>
#       <td id="T_39cdf_row3_col9" class="data row3 col9" >—</td>
#       <td id="T_39cdf_row3_col10" class="data row3 col10" >—</td>
#       <td id="T_39cdf_row3_col11" class="data row3 col11" >nan</td>
#       <td id="T_39cdf
# SMALLNORB:
# <style type="text/css">
# #T_147c7_ th {
#   text-align: center;
# }
# #T_147c7_row0_col0, #T_147c7_row0_col1, #T_147c7_row0_col2, #T_147c7_row0_col3, #T_147c7_row0_col4, #T_147c7_row0_col5, #T_147c7_row0_col6, #T_147c7_row0_col7, #T_147c7_row0_col8, #T_147c7_row0_col9, #T_147c7_row0_col10, #T_147c7_row0_col11, #T_147c7_row0_col12, #T_147c7_row1_col0, #T_147c7_row1_col1, #T_147c7_row1_col2, #T_147c7_row1_col3, #T_147c7_row1_col4, #T_147c7_row1_col5, #T_147c7_row1_col6, #T_147c7_row1_col7, #T_147c7_row1_col8, #T_147c7_row1_col9, #T_147c7_row1_col10, #T_147c7_row1_col11, #T_147c7_row1_col12, #T_147c7_row2_col0, #T_147c7_row2_col1, #T_147c7_row2_col2, #T_147c7_row2_col3, #T_147c7_row2_col4, #T_147c7_row2_col5, #T_147c7_row2_col6, #T_147c7_row2_col7, #T_147c7_row2_col8, #T_147c7_row2_col9, #T_147c7_row2_col10, #T_147c7_row2_col11, #T_147c7_row2_col12, #T_147c7_row3_col0, #T_147c7_row3_col1, #T_147c7_row3_col2, #T_147c7_row3_col3, #T_147c7_row3_col4, #T_147c7_row3_col5, #T_147c7_row3_col6, #T_147c7_row3_col7, #T_147c7_row3_col8, #T_147c7_row3_col9, #T_147c7_row3_col10, #T_147c7_row3_col11, #T_147c7_row3_col12, #T_147c7_row4_col0, #T_147c7_row4_col1, #T_147c7_row4_col2, #T_147c7_row4_col3, #T_147c7_row4_col4, #T_147c7_row4_col5, #T_147c7_row4_col6, #T_147c7_row4_col7, #T_147c7_row4_col8, #T_147c7_row4_col9, #T_147c7_row4_col10, #T_147c7_row4_col11, #T_147c7_row4_col12, #T_147c7_row5_col0, #T_147c7_row5_col1, #T_147c7_row5_col2, #T_147c7_row5_col3, #T_147c7_row5_col4, #T_147c7_row5_col5, #T_147c7_row5_col6, #T_147c7_row5_col7, #T_147c7_row5_col8, #T_147c7_row5_col9, #T_147c7_row5_col10, #T_147c7_row5_col11, #T_147c7_row5_col12, #T_147c7_row6_col0, #T_147c7_row6_col1, #T_147c7_row6_col2, #T_147c7_row6_col3, #T_147c7_row6_col4, #T_147c7_row6_col5, #T_147c7_row6_col6, #T_147c7_row6_col7, #T_147c7_row6_col8, #T_147c7_row6_col9, #T_147c7_row6_col10, #T_147c7_row6_col11, #T_147c7_row6_col12, #T_147c7_row7_col0, #T_147c7_row7_col1, #T_147c7_row7_col2, #T_147c7_row7_col3, #T_147c7_row7_col4, #T_147c7_row7_col5, #T_147c7_row7_col6, #T_147c7_row7_col7, #T_147c7_row7_col8, #T_147c7_row7_col9, #T_147c7_row7_col10, #T_147c7_row7_col11, #T_147c7_row7_col12, #T_147c7_row8_col0, #T_147c7_row8_col1, #T_147c7_row8_col2, #T_147c7_row8_col3, #T_147c7_row8_col4, #T_147c7_row8_col5, #T_147c7_row8_col6, #T_147c7_row8_col7, #T_147c7_row8_col8, #T_147c7_row8_col9, #T_147c7_row8_col10, #T_147c7_row8_col11, #T_147c7_row8_col12, #T_147c7_row9_col0, #T_147c7_row9_col1, #T_147c7_row9_col2, #T_147c7_row9_col3, #T_147c7_row9_col4, #T_147c7_row9_col5, #T_147c7_row9_col6, #T_147c7_row9_col7, #T_147c7_row9_col8, #T_147c7_row9_col9, #T_147c7_row9_col10, #T_147c7_row9_col11, #T_147c7_row9_col12, #T_147c7_row10_col0, #T_147c7_row10_col1, #T_147c7_row10_col2, #T_147c7_row10_col3, #T_147c7_row10_col4, #T_147c7_row10_col5, #T_147c7_row10_col6, #T_147c7_row10_col7, #T_147c7_row10_col8, #T_147c7_row10_col9, #T_147c7_row10_col10, #T_147c7_row10_col11, #T_147c7_row10_col12, #T_147c7_row11_col0, #T_147c7_row11_col1, #T_147c7_row11_col2, #T_147c7_row11_col3, #T_147c7_row11_col4, #T_147c7_row11_col5, #T_147c7_row11_col6, #T_147c7_row11_col7, #T_147c7_row11_col8, #T_147c7_row11_col9, #T_147c7_row11_col10, #T_147c7_row11_col11, #T_147c7_row11_col12, #T_147c7_row12_col0, #T_147c7_row12_col1, #T_147c7_row12_col2, #T_147c7_row12_col3, #T_147c7_row12_col4, #T_147c7_row12_col5, #T_147c7_row12_col6, #T_147c7_row12_col7, #T_147c7_row12_col8, #T_147c7_row12_col9, #T_147c7_row12_col10, #T_147c7_row12_col11, #T_147c7_row12_col12, #T_147c7_row13_col0, #T_147c7_row13_col1, #T_147c7_row13_col2, #T_147c7_row13_col3, #T_147c7_row13_col4, #T_147c7_row13_col5, #T_147c7_row13_col6, #T_147c7_row13_col7, #T_147c7_row13_col8, #T_147c7_row13_col9, #T_147c7_row13_col10, #T_147c7_row13_col11, #T_147c7_row13_col12, #T_147c7_row14_col0, #T_147c7_row14_col1, #T_147c7_row14_col2, #T_147c7_row14_col3, #T_147c7_row14_col4, #T_147c7_row14_col5, #T_147c7_row14_col6, #T_147c7_row14_col7, #T_147c7_row14_col8, #T_147c7_row14_col9, #T_147c7_row14_col10, #T_147c7_row14_col11, #T_147c7_row ...
#   text-align: center;
# }
# </style>
# <table id="T_147c7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Dataset</th>
#       <th class="col_heading level0 col1" >Batch Size</th>
#       <th class="col_heading level0 col2" >Epochs</th>
#       <th class="col_heading level0 col3" >Learning Rate</th>
#       <th class="col_heading level0 col4" >Scheduler</th>
#       <th class="col_heading level0 col5" >extra_caps</th>
#       <th class="col_heading level0 col6" >Routing Module</th>
#       <th class="col_heading level0 col7" >Dropout Probability</th>
#       <th class="col_heading level0 col8" >Number of Hypotheses</th>
#       <th class="col_heading level0 col9" >Subset Fraction</th>
#       <th class="col_heading level0 col10" >Similarity Metric</th>
#       <th class="col_heading level0 col11" >architecture</th>
#       <th class="col_heading level0 col12" >Test Error (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_147c7_level0_row0" class="row_heading level0 row0" >46</th>
#       <td id="T_147c7_row0_col0" class="data row0 col0" >smallnorb</td>
#       <td id="T_147c7_row0_col1" class="data row0 col1" >512</td>
#       <td id="T_147c7_row0_col2" class="data row0 col2" >250</td>
#       <td id="T_147c7_row0_col3" class="data row0 col3" >0.001</td>
#       <td id="T_147c7_row0_col4" class="data row0 col4" >plateau</td>
#       <td id="T_147c7_row0_col5" class="data row0 col5" >—</td>
#       <td id="T_147c7_row0_col6" class="data row0 col6" >Subset</td>
#       <td id="T_147c7_row0_col7" class="data row0 col7" >—</td>
#       <td id="T_147c7_row0_col8" class="data row0 col8" >—</td>
#       <td id="T_147c7_row0_col9" class="data row0 col9" >0.7</td>
#       <td id="T_147c7_row0_col10" class="data row0 col10" >MSE</td>
#       <td id="T_147c7_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_147c7_row0_col12" class="data row0 col12" >3.96 %</td>
#     </tr>
#     <tr>
#       <th id="T_147c7_level0_row1" class="row_heading level0 row1" >121</th>
#       <td id="T_147c7_row1_col0" class="data row1 col0" >smallnorb</td>
#       <td id="T_147c7_row1_col1" class="data row1 col1" >512</td>
#       <td id="T_147c7_row1_col2" class="data row1 col2" >250</td>
#       <td id="T_147c7_row1_col3" class="data row1 col3" >0.001</td>
#       <td id="T_147c7_row1_col4" class="data row1 col4" >—</td>
#       <td id="T_147c7_row1_col5" class="data row1 col5" >False</td>
#       <td id="T_147c7_row1_col6" class="data row1 col6" >Subset</td>
#       <td id="T_147c7_row1_col7" class="data row1 col7" >—</td>
#       <td id="T_147c7_row1_col8" class="data row1 col8" >—</td>
#       <td id="T_147c7_row1_col9" class="data row1 col9" >0.7</td>
#       <td id="T_147c7_row1_col10" class="data row1 col10" >cosine</td>
#       <td id="T_147c7_row1_col11" class="data row1 col11" >nan</td>
#       <td id="T_147c7_row1_col12" class="data row1 col12" >4.01 %</td>
#     </tr>
#     <tr>
#       <th id="T_147c7_level0_row2" class="row_heading level0 row2" >107</th>
#       <td id="T_147c7_row2_col0" class="data row2 col0" >smallnorb</td>
#       <td id="T_147c7_row2_col1" class="data row2 col1" >128</td>
#       <td id="T_147c7_row2_col2" class="data row2 col2" >250</td>
#       <td id="T_147c7_row2_col3" class="data row2 col3" >0.001</td>
#       <td id="T_147c7_row2_col4" class="data row2 col4" >—</td>
#       <td id="T_147c7_row2_col5" class="data row2 col
# FASHIONMNIST:
# <style type="text/css">
# #T_a7cbc_ th {
#   text-align: center;
# }
# #T_a7cbc_row0_col0, #T_a7cbc_row0_col1, #T_a7cbc_row0_col2, #T_a7cbc_row0_col3, #T_a7cbc_row0_col4, #T_a7cbc_row0_col5, #T_a7cbc_row0_col6, #T_a7cbc_row0_col7, #T_a7cbc_row0_col8, #T_a7cbc_row0_col9, #T_a7cbc_row0_col10, #T_a7cbc_row0_col11, #T_a7cbc_row0_col12, #T_a7cbc_row1_col0, #T_a7cbc_row1_col1, #T_a7cbc_row1_col2, #T_a7cbc_row1_col3, #T_a7cbc_row1_col4, #T_a7cbc_row1_col5, #T_a7cbc_row1_col6, #T_a7cbc_row1_col7, #T_a7cbc_row1_col8, #T_a7cbc_row1_col9, #T_a7cbc_row1_col10, #T_a7cbc_row1_col11, #T_a7cbc_row1_col12, #T_a7cbc_row2_col0, #T_a7cbc_row2_col1, #T_a7cbc_row2_col2, #T_a7cbc_row2_col3, #T_a7cbc_row2_col4, #T_a7cbc_row2_col5, #T_a7cbc_row2_col6, #T_a7cbc_row2_col7, #T_a7cbc_row2_col8, #T_a7cbc_row2_col9, #T_a7cbc_row2_col10, #T_a7cbc_row2_col11, #T_a7cbc_row2_col12, #T_a7cbc_row3_col0, #T_a7cbc_row3_col1, #T_a7cbc_row3_col2, #T_a7cbc_row3_col3, #T_a7cbc_row3_col4, #T_a7cbc_row3_col5, #T_a7cbc_row3_col6, #T_a7cbc_row3_col7, #T_a7cbc_row3_col8, #T_a7cbc_row3_col9, #T_a7cbc_row3_col10, #T_a7cbc_row3_col11, #T_a7cbc_row3_col12, #T_a7cbc_row4_col0, #T_a7cbc_row4_col1, #T_a7cbc_row4_col2, #T_a7cbc_row4_col3, #T_a7cbc_row4_col4, #T_a7cbc_row4_col5, #T_a7cbc_row4_col6, #T_a7cbc_row4_col7, #T_a7cbc_row4_col8, #T_a7cbc_row4_col9, #T_a7cbc_row4_col10, #T_a7cbc_row4_col11, #T_a7cbc_row4_col12, #T_a7cbc_row5_col0, #T_a7cbc_row5_col1, #T_a7cbc_row5_col2, #T_a7cbc_row5_col3, #T_a7cbc_row5_col4, #T_a7cbc_row5_col5, #T_a7cbc_row5_col6, #T_a7cbc_row5_col7, #T_a7cbc_row5_col8, #T_a7cbc_row5_col9, #T_a7cbc_row5_col10, #T_a7cbc_row5_col11, #T_a7cbc_row5_col12, #T_a7cbc_row6_col0, #T_a7cbc_row6_col1, #T_a7cbc_row6_col2, #T_a7cbc_row6_col3, #T_a7cbc_row6_col4, #T_a7cbc_row6_col5, #T_a7cbc_row6_col6, #T_a7cbc_row6_col7, #T_a7cbc_row6_col8, #T_a7cbc_row6_col9, #T_a7cbc_row6_col10, #T_a7cbc_row6_col11, #T_a7cbc_row6_col12, #T_a7cbc_row7_col0, #T_a7cbc_row7_col1, #T_a7cbc_row7_col2, #T_a7cbc_row7_col3, #T_a7cbc_row7_col4, #T_a7cbc_row7_col5, #T_a7cbc_row7_col6, #T_a7cbc_row7_col7, #T_a7cbc_row7_col8, #T_a7cbc_row7_col9, #T_a7cbc_row7_col10, #T_a7cbc_row7_col11, #T_a7cbc_row7_col12, #T_a7cbc_row8_col0, #T_a7cbc_row8_col1, #T_a7cbc_row8_col2, #T_a7cbc_row8_col3, #T_a7cbc_row8_col4, #T_a7cbc_row8_col5, #T_a7cbc_row8_col6, #T_a7cbc_row8_col7, #T_a7cbc_row8_col8, #T_a7cbc_row8_col9, #T_a7cbc_row8_col10, #T_a7cbc_row8_col11, #T_a7cbc_row8_col12, #T_a7cbc_row9_col0, #T_a7cbc_row9_col1, #T_a7cbc_row9_col2, #T_a7cbc_row9_col3, #T_a7cbc_row9_col4, #T_a7cbc_row9_col5, #T_a7cbc_row9_col6, #T_a7cbc_row9_col7, #T_a7cbc_row9_col8, #T_a7cbc_row9_col9, #T_a7cbc_row9_col10, #T_a7cbc_row9_col11, #T_a7cbc_row9_col12, #T_a7cbc_row10_col0, #T_a7cbc_row10_col1, #T_a7cbc_row10_col2, #T_a7cbc_row10_col3, #T_a7cbc_row10_col4, #T_a7cbc_row10_col5, #T_a7cbc_row10_col6, #T_a7cbc_row10_col7, #T_a7cbc_row10_col8, #T_a7cbc_row10_col9, #T_a7cbc_row10_col10, #T_a7cbc_row10_col11, #T_a7cbc_row10_col12, #T_a7cbc_row11_col0, #T_a7cbc_row11_col1, #T_a7cbc_row11_col2, #T_a7cbc_row11_col3, #T_a7cbc_row11_col4, #T_a7cbc_row11_col5, #T_a7cbc_row11_col6, #T_a7cbc_row11_col7, #T_a7cbc_row11_col8, #T_a7cbc_row11_col9, #T_a7cbc_row11_col10, #T_a7cbc_row11_col11, #T_a7cbc_row11_col12, #T_a7cbc_row12_col0, #T_a7cbc_row12_col1, #T_a7cbc_row12_col2, #T_a7cbc_row12_col3, #T_a7cbc_row12_col4, #T_a7cbc_row12_col5, #T_a7cbc_row12_col6, #T_a7cbc_row12_col7, #T_a7cbc_row12_col8, #T_a7cbc_row12_col9, #T_a7cbc_row12_col10, #T_a7cbc_row12_col11, #T_a7cbc_row12_col12, #T_a7cbc_row13_col0, #T_a7cbc_row13_col1, #T_a7cbc_row13_col2, #T_a7cbc_row13_col3, #T_a7cbc_row13_col4, #T_a7cbc_row13_col5, #T_a7cbc_row13_col6, #T_a7cbc_row13_col7, #T_a7cbc_row13_col8, #T_a7cbc_row13_col9, #T_a7cbc_row13_col10, #T_a7cbc_row13_col11, #T_a7cbc_row13_col12, #T_a7cbc_row14_col0, #T_a7cbc_row14_col1, #T_a7cbc_row14_col2, #T_a7cbc_row14_col3, #T_a7cbc_row14_col4, #T_a7cbc_row14_col5, #T_a7cbc_row14_col6, #T_a7cbc_row14_col7, #T_a7cbc_row14_col8, #T_a7cbc_row14_col9, #T_a7cbc_row14_col10, #T_a7cbc_row14_col11, #T_a7cbc_row ...
#   text-align: center;
# }
# </style>
# <table id="T_a7cbc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Dataset</th>
#       <th class="col_heading level0 col1" >Batch Size</th>
#       <th class="col_heading level0 col2" >Epochs</th>
#       <th class="col_heading level0 col3" >Learning Rate</th>
#       <th class="col_heading level0 col4" >Scheduler</th>
#       <th class="col_heading level0 col5" >extra_caps</th>
#       <th class="col_heading level0 col6" >Routing Module</th>
#       <th class="col_heading level0 col7" >Dropout Probability</th>
#       <th class="col_heading level0 col8" >Number of Hypotheses</th>
#       <th class="col_heading level0 col9" >Subset Fraction</th>
#       <th class="col_heading level0 col10" >Similarity Metric</th>
#       <th class="col_heading level0 col11" >architecture</th>
#       <th class="col_heading level0 col12" >Test Error (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7cbc_level0_row0" class="row_heading level0 row0" >108</th>
#       <td id="T_a7cbc_row0_col0" class="data row0 col0" >fashionmnist</td>
#       <td id="T_a7cbc_row0_col1" class="data row0 col1" >128</td>
#       <td id="T_a7cbc_row0_col2" class="data row0 col2" >400</td>
#       <td id="T_a7cbc_row0_col3" class="data row0 col3" >0.001</td>
#       <td id="T_a7cbc_row0_col4" class="data row0 col4" >—</td>
#       <td id="T_a7cbc_row0_col5" class="data row0 col5" >True</td>
#       <td id="T_a7cbc_row0_col6" class="data row0 col6" >WeightedAvg</td>
#       <td id="T_a7cbc_row0_col7" class="data row0 col7" >—</td>
#       <td id="T_a7cbc_row0_col8" class="data row0 col8" >—</td>
#       <td id="T_a7cbc_row0_col9" class="data row0 col9" >—</td>
#       <td id="T_a7cbc_row0_col10" class="data row0 col10" >—</td>
#       <td id="T_a7cbc_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_a7cbc_row0_col12" class="data row0 col12" >6.16 %</td>
#     </tr>
#     <tr>
#       <th id="T_a7cbc_level0_row1" class="row_heading level0 row1" >117</th>
#       <td id="T_a7cbc_row1_col0" class="data row1 col0" >fashionmnist</td>
#       <td id="T_a7cbc_row1_col1" class="data row1 col1" >64</td>
#       <td id="T_a7cbc_row1_col2" class="data row1 col2" >400</td>
#       <td id="T_a7cbc_row1_col3" class="data row1 col3" >0.001</td>
#       <td id="T_a7cbc_row1_col4" class="data row1 col4" >—</td>
#       <td id="T_a7cbc_row1_col5" class="data row1 col5" >True</td>
#       <td id="T_a7cbc_row1_col6" class="data row1 col6" >WeightedAvg</td>
#       <td id="T_a7cbc_row1_col7" class="data row1 col7" >—</td>
#       <td id="T_a7cbc_row1_col8" class="data row1 col8" >—</td>
#       <td id="T_a7cbc_row1_col9" class="data row1 col9" >—</td>
#       <td id="T_a7cbc_row1_col10" class="data row1 col10" >—</td>
#       <td id="T_a7cbc_row1_col11" class="data row1 col11" >nan</td>
#       <td id="T_a7cbc_row1_col12" class="data row1 col12" >6.26 %</td>
#     </tr>
#     <tr>
#       <th id="T_a7cbc_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_a7cbc_row2_col0" class="data row2 col0" >fashionmnist</td>
#       <td id="T_a7cbc_row2_col1" class="data row2 col1" >512</td>
#       <td id="T_a7cbc_row2_col2" class="data row2 col2" >400</td>
#       <td id="T_a7cbc_row2_col3" class="data row2 col3" >0.001</td>
#       <td id="T_a7cbc_row2_col4" class="data row2 col4" >—</td>
#       <td id="T_a7cbc_row2_col5" class="data row2
# SVHN:
# <style type="text/css">
# #T_3bd8f_ th {
#   text-align: center;
# }
# #T_3bd8f_row0_col0, #T_3bd8f_row0_col1, #T_3bd8f_row0_col2, #T_3bd8f_row0_col3, #T_3bd8f_row0_col4, #T_3bd8f_row0_col5, #T_3bd8f_row0_col6, #T_3bd8f_row0_col7, #T_3bd8f_row0_col8, #T_3bd8f_row0_col9, #T_3bd8f_row0_col10, #T_3bd8f_row0_col11, #T_3bd8f_row0_col12, #T_3bd8f_row1_col0, #T_3bd8f_row1_col1, #T_3bd8f_row1_col2, #T_3bd8f_row1_col3, #T_3bd8f_row1_col4, #T_3bd8f_row1_col5, #T_3bd8f_row1_col6, #T_3bd8f_row1_col7, #T_3bd8f_row1_col8, #T_3bd8f_row1_col9, #T_3bd8f_row1_col10, #T_3bd8f_row1_col11, #T_3bd8f_row1_col12, #T_3bd8f_row2_col0, #T_3bd8f_row2_col1, #T_3bd8f_row2_col2, #T_3bd8f_row2_col3, #T_3bd8f_row2_col4, #T_3bd8f_row2_col5, #T_3bd8f_row2_col6, #T_3bd8f_row2_col7, #T_3bd8f_row2_col8, #T_3bd8f_row2_col9, #T_3bd8f_row2_col10, #T_3bd8f_row2_col11, #T_3bd8f_row2_col12, #T_3bd8f_row3_col0, #T_3bd8f_row3_col1, #T_3bd8f_row3_col2, #T_3bd8f_row3_col3, #T_3bd8f_row3_col4, #T_3bd8f_row3_col5, #T_3bd8f_row3_col6, #T_3bd8f_row3_col7, #T_3bd8f_row3_col8, #T_3bd8f_row3_col9, #T_3bd8f_row3_col10, #T_3bd8f_row3_col11, #T_3bd8f_row3_col12, #T_3bd8f_row4_col0, #T_3bd8f_row4_col1, #T_3bd8f_row4_col2, #T_3bd8f_row4_col3, #T_3bd8f_row4_col4, #T_3bd8f_row4_col5, #T_3bd8f_row4_col6, #T_3bd8f_row4_col7, #T_3bd8f_row4_col8, #T_3bd8f_row4_col9, #T_3bd8f_row4_col10, #T_3bd8f_row4_col11, #T_3bd8f_row4_col12, #T_3bd8f_row5_col0, #T_3bd8f_row5_col1, #T_3bd8f_row5_col2, #T_3bd8f_row5_col3, #T_3bd8f_row5_col4, #T_3bd8f_row5_col5, #T_3bd8f_row5_col6, #T_3bd8f_row5_col7, #T_3bd8f_row5_col8, #T_3bd8f_row5_col9, #T_3bd8f_row5_col10, #T_3bd8f_row5_col11, #T_3bd8f_row5_col12, #T_3bd8f_row6_col0, #T_3bd8f_row6_col1, #T_3bd8f_row6_col2, #T_3bd8f_row6_col3, #T_3bd8f_row6_col4, #T_3bd8f_row6_col5, #T_3bd8f_row6_col6, #T_3bd8f_row6_col7, #T_3bd8f_row6_col8, #T_3bd8f_row6_col9, #T_3bd8f_row6_col10, #T_3bd8f_row6_col11, #T_3bd8f_row6_col12, #T_3bd8f_row7_col0, #T_3bd8f_row7_col1, #T_3bd8f_row7_col2, #T_3bd8f_row7_col3, #T_3bd8f_row7_col4, #T_3bd8f_row7_col5, #T_3bd8f_row7_col6, #T_3bd8f_row7_col7, #T_3bd8f_row7_col8, #T_3bd8f_row7_col9, #T_3bd8f_row7_col10, #T_3bd8f_row7_col11, #T_3bd8f_row7_col12, #T_3bd8f_row8_col0, #T_3bd8f_row8_col1, #T_3bd8f_row8_col2, #T_3bd8f_row8_col3, #T_3bd8f_row8_col4, #T_3bd8f_row8_col5, #T_3bd8f_row8_col6, #T_3bd8f_row8_col7, #T_3bd8f_row8_col8, #T_3bd8f_row8_col9, #T_3bd8f_row8_col10, #T_3bd8f_row8_col11, #T_3bd8f_row8_col12, #T_3bd8f_row9_col0, #T_3bd8f_row9_col1, #T_3bd8f_row9_col2, #T_3bd8f_row9_col3, #T_3bd8f_row9_col4, #T_3bd8f_row9_col5, #T_3bd8f_row9_col6, #T_3bd8f_row9_col7, #T_3bd8f_row9_col8, #T_3bd8f_row9_col9, #T_3bd8f_row9_col10, #T_3bd8f_row9_col11, #T_3bd8f_row9_col12, #T_3bd8f_row10_col0, #T_3bd8f_row10_col1, #T_3bd8f_row10_col2, #T_3bd8f_row10_col3, #T_3bd8f_row10_col4, #T_3bd8f_row10_col5, #T_3bd8f_row10_col6, #T_3bd8f_row10_col7, #T_3bd8f_row10_col8, #T_3bd8f_row10_col9, #T_3bd8f_row10_col10, #T_3bd8f_row10_col11, #T_3bd8f_row10_col12, #T_3bd8f_row11_col0, #T_3bd8f_row11_col1, #T_3bd8f_row11_col2, #T_3bd8f_row11_col3, #T_3bd8f_row11_col4, #T_3bd8f_row11_col5, #T_3bd8f_row11_col6, #T_3bd8f_row11_col7, #T_3bd8f_row11_col8, #T_3bd8f_row11_col9, #T_3bd8f_row11_col10, #T_3bd8f_row11_col11, #T_3bd8f_row11_col12, #T_3bd8f_row12_col0, #T_3bd8f_row12_col1, #T_3bd8f_row12_col2, #T_3bd8f_row12_col3, #T_3bd8f_row12_col4, #T_3bd8f_row12_col5, #T_3bd8f_row12_col6, #T_3bd8f_row12_col7, #T_3bd8f_row12_col8, #T_3bd8f_row12_col9, #T_3bd8f_row12_col10, #T_3bd8f_row12_col11, #T_3bd8f_row12_col12, #T_3bd8f_row13_col0, #T_3bd8f_row13_col1, #T_3bd8f_row13_col2, #T_3bd8f_row13_col3, #T_3bd8f_row13_col4, #T_3bd8f_row13_col5, #T_3bd8f_row13_col6, #T_3bd8f_row13_col7, #T_3bd8f_row13_col8, #T_3bd8f_row13_col9, #T_3bd8f_row13_col10, #T_3bd8f_row13_col11, #T_3bd8f_row13_col12, #T_3bd8f_row14_col0, #T_3bd8f_row14_col1, #T_3bd8f_row14_col2, #T_3bd8f_row14_col3, #T_3bd8f_row14_col4, #T_3bd8f_row14_col5, #T_3bd8f_row14_col6, #T_3bd8f_row14_col7, #T_3bd8f_row14_col8, #T_3bd8f_row14_col9, #T_3bd8f_row14_col10, #T_3bd8f_row14_col11, #T_3bd8f_row ...
#   text-align: center;
# }
# </style>
# <table id="T_3bd8f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Dataset</th>
#       <th class="col_heading level0 col1" >Batch Size</th>
#       <th class="col_heading level0 col2" >Epochs</th>
#       <th class="col_heading level0 col3" >Learning Rate</th>
#       <th class="col_heading level0 col4" >Scheduler</th>
#       <th class="col_heading level0 col5" >extra_caps</th>
#       <th class="col_heading level0 col6" >Routing Module</th>
#       <th class="col_heading level0 col7" >Dropout Probability</th>
#       <th class="col_heading level0 col8" >Number of Hypotheses</th>
#       <th class="col_heading level0 col9" >Subset Fraction</th>
#       <th class="col_heading level0 col10" >Similarity Metric</th>
#       <th class="col_heading level0 col11" >architecture</th>
#       <th class="col_heading level0 col12" >Test Error (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bd8f_level0_row0" class="row_heading level0 row0" >118</th>
#       <td id="T_3bd8f_row0_col0" class="data row0 col0" >svhn</td>
#       <td id="T_3bd8f_row0_col1" class="data row0 col1" >64</td>
#       <td id="T_3bd8f_row0_col2" class="data row0 col2" >400</td>
#       <td id="T_3bd8f_row0_col3" class="data row0 col3" >0.001</td>
#       <td id="T_3bd8f_row0_col4" class="data row0 col4" >—</td>
#       <td id="T_3bd8f_row0_col5" class="data row0 col5" >True</td>
#       <td id="T_3bd8f_row0_col6" class="data row0 col6" >WeightedAvg</td>
#       <td id="T_3bd8f_row0_col7" class="data row0 col7" >—</td>
#       <td id="T_3bd8f_row0_col8" class="data row0 col8" >—</td>
#       <td id="T_3bd8f_row0_col9" class="data row0 col9" >—</td>
#       <td id="T_3bd8f_row0_col10" class="data row0 col10" >—</td>
#       <td id="T_3bd8f_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_3bd8f_row0_col12" class="data row0 col12" >4.38 %</td>
#     </tr>
#     <tr>
#       <th id="T_3bd8f_level0_row1" class="row_heading level0 row1" >150</th>
#       <td id="T_3bd8f_row1_col0" class="data row1 col0" >svhn</td>
#       <td id="T_3bd8f_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_3bd8f_row1_col2" class="data row1 col2" >239</td>
#       <td id="T_3bd8f_row1_col3" class="data row1 col3" >0.001</td>
# CIFAR10:
# <style type="text/css">
# #T_72055_ th {
#   text-align: center;
# }
# #T_72055_row0_col0, #T_72055_row0_col1, #T_72055_row0_col2, #T_72055_row0_col3, #T_72055_row0_col4, #T_72055_row0_col5, #T_72055_row0_col6, #T_72055_row0_col7, #T_72055_row0_col8, #T_72055_row0_col9, #T_72055_row0_col10, #T_72055_row0_col11, #T_72055_row0_col12, #T_72055_row1_col0, #T_72055_row1_col1, #T_72055_row1_col2, #T_72055_row1_col3, #T_72055_row1_col4, #T_72055_row1_col5, #T_72055_row1_col6, #T_72055_row1_col7, #T_72055_row1_col8, #T_72055_row1_col9, #T_72055_row1_col10, #T_72055_row1_col11, #T_72055_row1_col12, #T_72055_row2_col0, #T_72055_row2_col1, #T_72055_row2_col2, #T_72055_row2_col3, #T_72055_row2_col4, #T_72055_row2_col5, #T_72055_row2_col6, #T_72055_row2_col7, #T_72055_row2_col8, #T_72055_row2_col9, #T_72055_row2_col10, #T_72055_row2_col11, #T_72055_row2_col12, #T_72055_row3_col0, #T_72055_row3_col1, #T_72055_row3_col2, #T_72055_row3_col3, #T_72055_row3_col4, #T_72055_row3_col5, #T_72055_row3_col6, #T_72055_row3_col7, #T_72055_row3_col8, #T_72055_row3_col9, #T_72055_row3_col10, #T_72055_row3_col11, #T_72055_row3_col12, #T_72055_row4_col0, #T_72055_row4_col1, #T_72055_row4_col2, #T_72055_row4_col3, #T_72055_row4_col4, #T_72055_row4_col5, #T_72055_row4_col6, #T_72055_row4_col7, #T_72055_row4_col8, #T_72055_row4_col9, #T_72055_row4_col10, #T_72055_row4_col11, #T_72055_row4_col12, #T_72055_row5_col0, #T_72055_row5_col1, #T_72055_row5_col2, #T_72055_row5_col3, #T_72055_row5_col4, #T_72055_row5_col5, #T_72055_row5_col6, #T_72055_row5_col7, #T_72055_row5_col8, #T_72055_row5_col9, #T_72055_row5_col10, #T_72055_row5_col11, #T_72055_row5_col12, #T_72055_row6_col0, #T_72055_row6_col1, #T_72055_row6_col2, #T_72055_row6_col3, #T_72055_row6_col4, #T_72055_row6_col5, #T_72055_row6_col6, #T_72055_row6_col7, #T_72055_row6_col8, #T_72055_row6_col9, #T_72055_row6_col10, #T_72055_row6_col11, #T_72055_row6_col12, #T_72055_row7_col0, #T_72055_row7_col1, #T_72055_row7_col2, #T_72055_row7_col3, #T_72055_row7_col4, #T_72055_row7_col5, #T_72055_row7_col6, #T_72055_row7_col7, #T_72055_row7_col8, #T_72055_row7_col9, #T_72055_row7_col10, #T_72055_row7_col11, #T_72055_row7_col12, #T_72055_row8_col0, #T_72055_row8_col1, #T_72055_row8_col2, #T_72055_row8_col3, #T_72055_row8_col4, #T_72055_row8_col5, #T_72055_row8_col6, #T_72055_row8_col7, #T_72055_row8_col8, #T_72055_row8_col9, #T_72055_row8_col10, #T_72055_row8_col11, #T_72055_row8_col12, #T_72055_row9_col0, #T_72055_row9_col1, #T_72055_row9_col2, #T_72055_row9_col3, #T_72055_row9_col4, #T_72055_row9_col5, #T_72055_row9_col6, #T_72055_row9_col7, #T_72055_row9_col8, #T_72055_row9_col9, #T_72055_row9_col10, #T_72055_row9_col11, #T_72055_row9_col12, #T_72055_row10_col0, #T_72055_row10_col1, #T_72055_row10_col2, #T_72055_row10_col3, #T_72055_row10_col4, #T_72055_row10_col5, #T_72055_row10_col6, #T_72055_row10_col7, #T_72055_row10_col8, #T_72055_row10_col9, #T_72055_row10_col10, #T_72055_row10_col11, #T_72055_row10_col12, #T_72055_row11_col0, #T_72055_row11_col1, #T_72055_row11_col2, #T_72055_row11_col3, #T_72055_row11_col4, #T_72055_row11_col5, #T_72055_row11_col6, #T_72055_row11_col7, #T_72055_row11_col8, #T_72055_row11_col9, #T_72055_row11_col10, #T_72055_row11_col11, #T_72055_row11_col12, #T_72055_row12_col0, #T_72055_row12_col1, #T_72055_row12_col2, #T_72055_row12_col3, #T_72055_row12_col4, #T_72055_row12_col5, #T_72055_row12_col6, #T_72055_row12_col7, #T_72055_row12_col8, #T_72055_row12_col9, #T_72055_row12_col10, #T_72055_row12_col11, #T_72055_row12_col12, #T_72055_row13_col0, #T_72055_row13_col1, #T_72055_row13_col2, #T_72055_row13_col3, #T_72055_row13_col4, #T_72055_row13_col5, #T_72055_row13_col6, #T_72055_row13_col7, #T_72055_row13_col8, #T_72055_row13_col9, #T_72055_row13_col10, #T_72055_row13_col11, #T_72055_row13_col12, #T_72055_row14_col0, #T_72055_row14_col1, #T_72055_row14_col2, #T_72055_row14_col3, #T_72055_row14_col4, #T_72055_row14_col5, #T_72055_row14_col6, #T_72055_row14_col7, #T_72055_row14_col8, #T_72055_row14_col9, #T_72055_row14_col10, #T_72055_row14_col11, #T_72055_row ...
#   text-align: center;
# }
# </style>
# <table id="T_72055_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Dataset</th>
#       <th class="col_heading level0 col1" >Batch Size</th>
#       <th class="col_heading level0 col2" >Epochs</th>
#       <th class="col_heading level0 col3" >Learning Rate</th>
#       <th class="col_heading level0 col4" >Scheduler</th>
#       <th class="col_heading level0 col5" >extra_caps</th>
#       <th class="col_heading level0 col6" >Routing Module</th>
#       <th class="col_heading level0 col7" >Dropout Probability</th>
#       <th class="col_heading level0 col8" >Number of Hypotheses</th>
#       <th class="col_heading level0 col9" >Subset Fraction</th>
#       <th class="col_heading level0 col10" >Similarity Metric</th>
#       <th class="col_heading level0 col11" >architecture</th>
#       <th class="col_heading level0 col12" >Test Error (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72055_level0_row0" class="row_heading level0 row0" >119</th>
#       <td id="T_72055_row0_col0" class="data row0 col0" >cifar10</td>
#       <td id="T_72055_row0_col1" class="data row0 col1" >64</td>
#       <td id="T_72055_row0_col2" class="data row0 col2" >400</td>
#       <td id="T_72055_row0_col3" class="data row0 col3" >0.001</td>
#       <td id="T_72055_row0_col4" class="data row0 col4" >—</td>
#       <td id="T_72055_row0_col5" class="data row0 col5" >True</td>
#       <td id="T_72055_row0_col6" class="data row0 col6" >WeightedAvg</td>
#       <td id="T_72055_row0_col7" class="data row0 col7" >—</td>
#       <td id="T_72055_row0_col8" class="data row0 col8" >—</td>
#       <td id="T_72055_row0_col9" class="data row0 col9" >—</td>
#       <td id="T_72055_row0_col10" class="data row0 col10" >—</td>
#       <td id="T_72055_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_72055_row0_col12" class="data row0 col12" >15.35 %</td>
#     </tr>
#     <tr>
#       <th id="T_72055_level0_row1" class="row_heading level0 row1" >151</th>
#       <td id="T_72055_row1_col0" class="data row1 col0" >cifar10</td>
#       <td id="T_72055_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_72055_row1_col2" class="data row1 col2" >332</td>
#       <td id="T_72055_row1_col3" class="data row1 col3" >0.001</td>
#       <td id="T_72055_row1_col4" class="data row1 col4" >—</td>
#       <td id="T_72055_row1_col5" class="data row1 col5" >True</td>
#       <td id="T_72055_row1_col6" class="data row1 col6" >WeightedAvg</td>
#       <td id="T_72055_row1_col7" class="data row1 col7" >—</td>
#       <td id="T_72055_row1_col8" class="data row1 col8" >—</td>
#       <td id="T_72055_row1_col9" class="data row1 col9" >—</td>
#       <td id="T_72055_row1_col10" class="data row1 col10" >—</td>
#       <td id="T_72055_row1_col11" class="data row1 col11" >CapsNet</td>
#       <td id="T_72055_row1_col12" class="data row1 col12" >15.46 %</td>
#     </tr>
#     <tr>
#       <th id="T_72055_level0_row2" class="row_heading level0 row2" >116</th>
#       <td id="T_72055_row2_col0" class="data row2 col0" >cifar10</td>
#       <td id="T_72055_row2_col1" class="data row2 col1" >128</td>
#       <td id="T_72055_row2_col2" class="data row2 col2" >400</td>
#       <td id="T_72055_row2_col3" class="data row2 col3" >0.001</td>
#       <td id="T_72055_row2_col4" class="data row2 col4" >—</td>
#       <td id="T_72055_row2_col5" class="data row2 col5" >Tru
